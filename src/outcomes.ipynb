# %%
import pandas as pd


df = pd.read_csv("outcome.csv")
df.head()

new_df = pd.read_csv('pregnancy_outcome.csv')
df = pd.merge(df, new_df[['PublicID', 'New_Column']], on='PublicID', how='left')
# Out:
#   PublicID  MH_outcome
# 0   00004O           1
# 1   00007I           1
# 2   00008G           0
# 3   00015J           0
# 4   00016H           1

# %%
df_baby = pd.read_csv("CBA.csv",usecols = ['CBAA04a', 'CBAA04b'],encoding='utf-8')
# Out:
# C:\Users\91799\AppData\Local\Temp\ipykernel_14824\3543009678.py:1: DtypeWarning: Columns (20,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_baby = pd.read_csv("CBA.csv",usecols = ['CBAA04a', 'CBAA04b'],encoding='utf-8')
